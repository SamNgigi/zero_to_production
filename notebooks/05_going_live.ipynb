// %% [markdown]
// # 05. Going Live (Axum deployment

// %% [markdown]
// ## 05.3. A Docker File for Our Application

// %% [markdown]
// ## 05.4. Deploy to Fly.io

// %% [markdown]
// ### 05.4.1. Setup

// %% [markdown]
// ### 05.4.2. App Specification

// %% [markdown]
// ### 05.4.3. How to Inject Secrets Using Environment Variables

// %% [markdown]
// ### 05.4.4. Connecting to Fly.io Postgres Instance

// %% [markdown]
// ### 05.4.5. Environment Variables in The App Spec

// %% [markdown]
// ### 05.4.6. One Last Push
